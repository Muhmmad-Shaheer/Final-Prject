# %%
def shut_down(s):
    
    print("1: To proceed with shutting down your program, type (Yes) in the function.")
    print("2: To proceed with cancelling shutting down your program, type (No) in the function.")
    
    s = input("Enter any command to proceed further:")   
  
    if s == "Yes" or s == "yes":
        return print("Shutting Down...Program has been shut down...Program has been shut down.")
    elif s == "No" or s == "no":
        return print("! ShutDown aborted...")
    else:
        return print("Sorry,you have entered an invalid command, enter the valid commands in order to proceed.")

# %%
shut_down("s")
# Out:
# 1: To proceed with shutting down your program, type (Yes) in the function.
# 2: To proceed with cancelling shutting down your program, type (No) in the function.
# Enter any command to proceed further:yes
# Shutting Down...Program has been shut down...Program has been shut down.

# %%
shut_down("s")
# Out:
# 1: To proceed with shutting down your program, type (Yes) in the function.
# 2: To proceed with cancelling shutting down your program, type (No) in the function.
# Enter any command to proceed further:no
# ! ShutDown aborted...

# %%
import matplotlib.pyplot as plt 
import pandas as pd 

data = {"x":[0,1,2,3,4,5,6,7,8] , 
        "y":[10,30,20,50,60,32,35,12,30]}
graph = pd.DataFrame(data)
graph.plot(x="x" , y="y",linestyle="--",color="lightseagreen",marker="*",markerfacecolor="red",markersize=10)
plt.title("Graph Title")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.show()

# %%
count=1
while count<=20:
    if count%2==0:
        print(count)
    count=count+1
    if count ==12:
        print("Done")
        break
# Out:
# 2
# 4
# 6
# 8
# 10
# Done

# %%
for i in "Myblog":
    print(i,'?')
# Out:
# M ?
# y ?
# b ?
# l ?
# o ?
# g ?

# %%
import pandas as pd
import matplotlib.pyplot as plt

newdata = { "x":[0,0.8,2,3,4,4.9,6,7.1,7.9,8.6] ,
            "y":[1.2,0.9,-1.2,0.7,-1.4,-1.6,1.5,0.8,0.1,-2.0]  }

newgraph = pd.DataFrame(newdata)
newgraph.plot(x="x",y="y",color="blue",marker="o",markerfacecolor="white",markersize=12)

plt.xlabel
# Out:
# <function matplotlib.pyplot.xlabel(xlabel, fontdict=None, labelpad=None, *, loc=None, **kwargs)>

# %%
#Registration form
#Import openpyxl and tkinter libraries:
from openpyxl import *
from tkinter import *
 
#Load your excel workbook using the file path:
wb = load_workbook("C:/Python/Datasets/Registration Form (Final Project).xlsx")

sheet = wb.active
# Define dimensions and your values:
 
def excel():
    
    sheet.column_dimensions['A'].width = 30
    sheet.column_dimensions['B'].width = 10
    sheet.column_dimensions['C'].width = 10
    sheet.column_dimensions['D'].width = 20
    sheet.column_dimensions['E'].width = 20
    sheet.column_dimensions['F'].width = 40
    sheet.column_dimensions['G'].width = 50

    sheet.cell(row=1, column=1).value = "Name"
    sheet.cell(row=1, column=2).value = "Course"
    sheet.cell(row=1, column=3).value = "Semester"
    sheet.cell(row=1, column=4).value = "Form Number"
    sheet.cell(row=1, column=5).value = "Contact Number"
    sheet.cell(row=1, column=6).value = "Email id"
    sheet.cell(row=1, column=7).value = "Address"
 
 

def focus1(event):
    course_field.focus_set()
 
 

def focus2(event):
    sem_field.focus_set()
 

def focus3(event):
    form_no_field.focus_set()
 

def focus4(event):
    contact_no_field.focus_set()
 
def focus5(event):
    email_id_field.focus_set()
 
def focus6(event):
    address_field.focus_set()
 
def clear():
     
    name_field.delete(0, END)
    course_field.delete(0, END)
    sem_field.delete(0, END)
    form_no_field.delete(0, END)
    contact_no_field.delete(0, END)
    email_id_field.delete(0, END)
    address_field.delete(0, END)
    
# Event if the user gives no input:

def insert():
     
    if (name_field.get() == "" and
        course_field.get() == "" and
        sem_field.get() == "" and
        form_no_field.get() == "" and
        contact_no_field.get() == "" and
        email_id_field.get() == "" and
        address_field.get() == ""):
             
        Empty = Label(root, text="Some fields may be empty!", bg="lightblue",fg='red')
        Empty.grid(row=10, column=1)
    else:
 
        current_row = sheet.max_row
        current_column = sheet.max_column
 
        sheet.cell(row=current_row + 1, column=1).value = name_field.get()
        sheet.cell(row=current_row + 1, column=2).value = course_field.get()
        sheet.cell(row=current_row + 1, column=3).value = sem_field.get()
        sheet.cell(row=current_row + 1, column=4).value = form_no_field.get()
        sheet.cell(row=current_row + 1, column=5).value = contact_no_field.get()
        sheet.cell(row=current_row + 1, column=6).value = email_id_field.get()
        sheet.cell(row=current_row + 1, column=7).value = address_field.get()

# Saving the information in the excel file by the file path:       

        wb.save("C:/Python/Datasets/Registration Form (Final Project).xlsx")
        name_field.focus_set()
       
        clear()

# Setting-up and designing the GUI:

if __name__ == "__main__":

    root = Tk()
 

    root.configure(background='lightblue')
    root.title("Registration Form")
 
    root.geometry("500x300")
    excel()
    heading = Label(root, text="Shaheer's Registration Form", bg="lightblue",fg='darkblue')
    name = Label(root, text="Name:", bg="lightblue")
    course = Label(root, text="Course:", bg="lightblue")
    sem = Label(root, text="Semester:", bg="lightblue")
    form_no = Label(root, text="Form No. :", bg="lightblue")
    contact_no = Label(root, text="Contact No. :", bg="lightblue")
    email_id = Label(root, text="Email Id:", bg="lightblue")
    address = Label(root, text="Address:", bg="lightblue")
 
 # Positioning and aligning the values:
    heading.grid(row=0, column=1)
    name.grid(row=1, column=0)
    course.grid(row=2, column=0)
    sem.grid(row=3, column=0)
    form_no.grid(row=4, column=0)
    contact_no.grid(row=5, column=0)
    email_id.grid(row=6, column=0)
    address.grid(row=7, column=0)
    
 # Creating entry fields:
    
    name_field = Entry(root)
    course_field = Entry(root)
    sem_field = Entry(root)
    form_no_field = Entry(root)
    contact_no_field = Entry(root)
    email_id_field = Entry(root)
    address_field = Entry(root)
    
 # Binding the focus events:
 
    name_field.bind("<Return>", focus1)
    course_field.bind("<Return>", focus2)
    sem_field.bind("<Return>", focus3)
    form_no_field.bind("<Return>", focus4)
    contact_no_field.bind("<Return>", focus5)
    email_id_field.bind("<Return>", focus6)
    
# Aligning the grid values:    
 
    name_field.grid(row=1, column=1, ipadx="100")
    course_field.grid(row=2, column=1, ipadx="100")
    sem_field.grid(row=3, column=1, ipadx="100")
    form_no_field.grid(row=4, column=1, ipadx="100")
    contact_no_field.grid(row=5, column=1, ipadx="100")
    email_id_field.grid(row=6, column=1, ipadx="100")
    address_field.grid(row=7, column=1, ipadx="100")

# Calling the excel function:

    excel()
# Creating a submit button: 

    Button(text='Submit',command=insert,bg='black',fg='white',font=" ar 10").grid(row=8,column=1)
    
# Starting the GUI:
 
    root.mainloop()

# %%
#output of code

for letter in "word":
    print(letter,end="")
# Out:
# word

# %%
#skipped 2nd last letter

for letter in "word": 
    if letter =="r":
        continue
    print(letter,end="")
# Out:
# wod
